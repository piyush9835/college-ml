# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush9835/college-ml/blob/main/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("result1.xlsx", sheet_name="Sheet1")

# %%
grade_mapping = {"A+": 10, "A":9, "B+": 8, "B": 7, "C": 5, "D": 4,"F": 0, "AB": 0, "P": 4}

# %%
df.replace(grade_mapping, inplace=True)

# %%
df.to_excel("updated_result1.xlsx", index=False)

# %%
df1=df.to_csv("updated_result1.csv", index=False)

# %%
df1=pd.read_csv("updated_result1.csv")

# %%
df1
# Out:
#    Unnamed: 0 ML Theory Unnamed: 2 Unnamed: 3 Unnamed: 4    ML Lab Unnamed: 6  \
# 0      S. No.  Internal   External      Total       Grde  Internal   External
# 1           1        37         36         73          0      25.5         28
# 2           2        61         75        136          8      30.5         38
# 3           3        50         48         98          5        27         32
# 4           4        57         48        105          5        33         38
# ..        ...       ...        ...        ...        ...       ...        ...
# 57         57        57         33         90          5      29.5         34
# 58         58        34         AB         34         AB      23.5         29
# 59         59        46         32         78          0      22.5         32
# 60         60        51         31         82          P        29         30
# 61         61        41         39         80          P        23         34
#
# ...
