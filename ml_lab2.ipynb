# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush9835/college-ml/blob/main/ml_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('student.xlsx')

# Convert and save as CSV
df.to_csv('student.csv', index=False)

# %%
# Load the CSV file
df = pd.read_csv('student.csv')

# Get the number of rows and columns
num_rows, num_columns = df.shape

print(f"The file has {num_rows} rows and {num_columns} columns.")
# Out:
# The file has 63 rows and 19 columns.

# %%
df = pd.read_csv('student.csv')
row_data = df[df['Roll No.'] == '1/22/FET/BCS/041']
row_data
# Out:
#     S.No. Semester                           Branch /Course  \
# 37   37.0    5CSA2  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 37                                        22/FET/0096
#
#    Date of Admission in the Present Class/Course          Roll No.  \
# 37                                    29.07.2024  1/22/FET/BCS/041
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 37                                              MOHIT
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN  \
# 37                                       YADVIR SINGH
#
#    Gender  Religion Category Aadhaar No. of Student  \
# 37   MALE  HINDUISM  GENERAL           915588325333
#
#     Updated Mobile No. of Student       Updated E-mail ID    State  \
# 37                   8.178359e+09  MOHITATRI052@GMAIL.COM  HARYANA
#
# ...

# %%
selected_columns = row_data[['Semester', 'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN','Updated Mobile No. of Student']]

# %%
selected_columns
# Out:
#    Semester  \
# 37    5CSA2
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 37                                              MOHIT
#
#     Updated Mobile No. of Student
# 37                   8.178359e+09

# %%
male = df[df['Gender']=='MALE']
female = df[df['Gender']=='FEMALE']
male
female
# Out:
#     S.No. Semester                           Branch /Course  \
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 9     9.0    5CSA1  B.Tech - Computer Science & Engineering
# 20   20.0    5CSA1  B.Tech - Computer Science & Engineering
# 22   22.0    5CSA1  B.Tech - Computer Science & Engineering
# 25   25.0    5CSA1  B.Tech - Computer Science & Engineering
# 26   26.0    5CSA1  B.Tech - Computer Science & Engineering
# 30   30.0    5CSA2  B.Tech - Computer Science & Engineering
# 34   34.0    5CSA2  B.Tech - Computer Science & Engineering
# 35   35.0    5CSA2  B.Tech - Computer Science & Engineering
# 38   38.0    5CSA2  B.Tech - Computer Science & Engineering
# 47   47.0    5CSA2  B.Tech - Computer Science & Engineering
# 54   54.0    5CSA2  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 2                                         22/FET/0063
# ...

# %%
male
# Out:
#     S.No. Semester                           Branch /Course  \
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# 5     5.0    5CSA1  B.Tech - Computer Science & Engineering
# 6     6.0    5CSA1  B.Tech - Computer Science & Engineering
# 7     7.0    5CSA1  B.Tech - Computer Science & Engineering
# 8     8.0    5CSA1  B.Tech - Computer Science & Engineering
# 10   10.0    5CSA1  B.Tech - Computer Science & Engineering
# 11   11.0    5CSA1  B.Tech - Computer Science & Engineering
# 12   12.0    5CSA1  B.Tech - Computer Science & Engineering
# 13   13.0    5CSA1  B.Tech - Computer Science & Engineering
# 14   14.0    5CSA1  B.Tech - Computer Science & Engineering
# 15   15.0    5CSA1  B.Tech - Computer Science & Engineering
# 16   16.0    5CSA1  B.Tech - Computer Science & Engineering
# 17   17.0    5CSA1  B.Tech - Computer Science & Engineering
# ...

# %%
mentor = df[df['mentors']=='Dr POONAM NANDAL']
mentor
# Out:
#    S.No. Semester                           Branch /Course  \
# 5    5.0    5CSA1  B.Tech - Computer Science & Engineering
# 6    6.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 5                                        22/FET/0066
# 6                                        22/FET/0067
#
#   Date of Admission in the Present Class/Course          Roll No.  \
# 5                                    29.07.2024  1/22/FET/BCS/006
# 6                                    29.07.2024  1/22/FET/BCS/007
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 5                                       SHIVAM SINGH
# 6                                         ATUL KUMAR
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN  \
# 5                                         GYAN SINGH
# 6                                       RAVINDRA RAI
#
# ...

# %%
grouped = df.groupby('Category')
grouped

# %%
state= df[df['State']=='DELHI']
state
# Out:
#     S.No. Semester                           Branch /Course  \
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# 9     9.0    5CSA1  B.Tech - Computer Science & Engineering
# 13   13.0    5CSA1  B.Tech - Computer Science & Engineering
# 21   21.0    5CSA1  B.Tech - Computer Science & Engineering
# 26   26.0    5CSA1  B.Tech - Computer Science & Engineering
# 28   28.0    5CSA1  B.Tech - Computer Science & Engineering
# 29   29.0    5CSA2  B.Tech - Computer Science & Engineering
# 30   30.0    5CSA2  B.Tech - Computer Science & Engineering
# 33   33.0    5CSA2  B.Tech - Computer Science & Engineering
# 46   46.0    5CSA2  B.Tech - Computer Science & Engineering
# 50   50.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 4                                         22/FET/0065
# 9                                         22/FET/0519
# ...

# %%
adhar = df[df['Aadhaar No. of Student']=='']
adhar
# Out:
# Empty DataFrame
# Columns: [S.No., Semester, Branch /Course, University Registration No. (Issued by R&S Branch), Date of Admission in the Present Class/Course, Roll No., Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN, Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN, Gender, Religion, Category, Aadhaar No. of Student, Updated Mobile No. of Student, Updated E-mail ID, State, Total Due Fee for Current Semester / (Previous semester if pending), Fee Paid for Current Semester / (Previous semester if pending), mentors, Unnamed: 18]
# Index: []

# %%
for category, group in grouped:
    print(f"Category: {category}")
    print(group[['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN']])  # Print only the 'Name' column for students in that category
    print("\n" + "-"*50 + "\n")
# Out:
# Category: GENERAL
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 2                                   KUMARI JAN NASHIN
# 4                               SUMIT KUMAR CHAURASIA
# 6                                          ATUL KUMAR
# 7                                            ABHISHEK
# 8                                     ANIRUDDH SHARMA
# 10                                 SIDDHARTH BHARDWAJ
# 11                                       KRISHNA NEGI
# 12                                      AKASH MALLICK
# 13                           KRISHAN KANT KANT SHARMA
# 14                                      MAYANK TANWAR
# 15                                        HARSH SINGH
# 16                                       TUSHAR RAWAT
# 17                                      SOURAV RAJPUT
# 18                                 MUGDH KUMAR SHARMA
# 19                                    SHASHANK PANDEY
# ...

# %%
cols=df[['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN','Roll No.','mentors']]
cols
# Out:
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 0                                     Name of Student
# 1                                          YASH VERMA
# 2                                   KUMARI JAN NASHIN
# 3                                        MANAS RANJAN
# 4                               SUMIT KUMAR CHAURASIA
# ..                                                ...
# 58                                   HANI SINGH RAWAT
# 59                                      VINAY KHULBEY
# 60                                           Arsh Jha
# 61                                     HANSHIKA YADAV
# 62                                         YASH YADAV
#
#             Roll No.                   mentors
# 0                NaN                       NaN
# 1   1/22/FET/BCS/002           Dr SURESH KUMAR
# 2   1/22/FET/BCS/003        Ms SAMEEKSHA KHARE
# 3   1/22/FET/BCS/004           Dr INDU KASHYAP
# ...

# %%
dues=df[df['Fee Paid for Current Semester / (Previous semester if pending)']!=0.0]
dues
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#     S.No. Semester                           Branch /Course  \
# 0     NaN      NaN                                      NaN
# 15   15.0    5CSA1  B.Tech - Computer Science & Engineering
# 24   24.0    5CSA1  B.Tech - Computer Science & Engineering
# 39   39.0    5CSA2  B.Tech - Computer Science & Engineering
# 62   62.0    5CSA2                                      NaN
#
#    University Registration No. (Issued by R&S Branch)  \
# 0                                                 NaN
# 15                                        22/FET/0075
# 24                                        22/FET/0084
# 39                                        22/FET/0098
# ...

# %%
total_pending = df['Total Due Fee for Current Semester / (Previous semester if pending)'].sum()
total_pending
# Out:
# 477519.72
